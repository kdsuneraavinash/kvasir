# %%
import fastai.vision as vision
import torch
import pathlib

# %%
vision.defaults.device = torch.device('cpu')

# %%
learn = vision.load_learner(path="assassins")

# %%
test_dir = pathlib.Path("assassins/test")

# %%
images = vision.get_image_files(test_dir)

_, axs = plt.subplots(len(images)//3, 3, figsize=(12,11))
axs = axs.flatten()

for ind, image in enumerate(images):
    img = vision.open_image(image)
    class_name, label, prob = learn.predict(img)
    p = prob[label.item()].item()
    img.show(axs[ind], title=f"{class_name}: {p*100:.2f}%")
